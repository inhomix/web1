# %% [markdown]
# <a href="https://colab.research.google.com/github/inhomix/web1/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install finterstellar
# Out:
# Requirement already satisfied: finterstellar in /usr/local/lib/python3.7/dist-packages (0.1.14)
# Requirement already satisfied: pandas-datareader>=0.10.0 in /usr/local/lib/python3.7/dist-packages (from finterstellar) (0.10.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.7/dist-packages (from finterstellar) (1.1.5)
# Requirement already satisfied: lxml>=4.2.6 in /usr/local/lib/python3.7/dist-packages (from finterstellar) (4.2.6)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.7/dist-packages (from finterstellar) (2.23.0)
# Requirement already satisfied: numpy>=1.19.3 in /usr/local/lib/python3.7/dist-packages (from finterstellar) (1.19.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1.4->finterstellar) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1.4->finterstellar) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=1.1.4->finterstellar) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.23.0->finterstellar) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.23.0->finterstellar) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.23.0->finterstellar) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.23.0->finterstellar) (2.10)

# %%
import finterstellar as fs
df = fs.get_price('AAPL', start_date = '2020-01-01', end_date = '2021-12-31')
print(df)
# Out:
# Symbols      AAPL
# Date
# 2020-01-02  75.09
# 2020-01-03  74.36
# 2020-01-06  74.95
# 2020-01-07  74.60
# 2020-01-08  75.80
# ...           ...
# 2021-12-27 180.33
# 2021-12-28 179.29
# 2021-12-29 179.38
# 2021-12-30 178.20
# 2021-12-31 177.57
#
# [505 rows x 1 columns]

# %%
fs.draw_chart(df, right = 'AAPL')

# %%
fs.rsi(df, w=14)
fs.draw_chart(df, left = 'rsi', right = 'AAPL')

# %%
fs.indicator_to_signal(df, factor = 'rsi', buy = 40, sell = 60)
# Out:
# Date
# 2020-01-02    zero
# 2020-01-03    zero
# 2020-01-06    zero
# 2020-01-07    zero
# 2020-01-08    zero
#               ...
# 2021-12-27    zero
# 2021-12-28    zero
# 2021-12-29    zero
# 2021-12-30    zero
# 2021-12-31    zero
# Name: trade, Length: 505, dtype: object

# %%
fs.position(df)
fs.draw_chart(df, left = 'rsi', right = 'position_chart')

# %%
df
# Out:
# Symbols      AAPL  diff   au   ad   rsi trade position  position_chart
# Date
# 2020-01-02  75.09   nan  nan  nan   nan  zero                        0
# 2020-01-03  74.36 -0.73  nan  nan   nan  zero       zz               0
# 2020-01-06  74.95  0.59  nan  nan   nan  zero       zz               0
# 2020-01-07  74.60 -0.35  nan  nan   nan  zero       zz               0
# 2020-01-08  75.80  1.20  nan  nan   nan  zero       zz               0
# ...           ...   ...  ...  ...   ...   ...      ...             ...
# 2021-12-27 180.33  4.05 1.79 0.89 66.89  zero       zz               0
# 2021-12-28 179.29 -1.04 1.66 0.90 64.95  zero       zz               0
# 2021-12-29 179.38  0.09 1.55 0.83 65.04  zero       zz               0
# 2021-12-30 178.20 -1.18 1.44 0.86 62.66  zero       zz               0
# 2021-12-31 177.57 -0.63 1.34 0.84 61.37  zero       zz               0
#
# [505 rows x 8 columns]

# %%
fs.evaluate(df,cost=.001)
fs.draw_chart(df, left = 'acc_rtn_dp', right = 'AAPL')

# %%
fs.performance(df,rf_rate=0.01)
# Out:
# CAGR: 14.75%
# Accumulated return: 30.63%
# Average return: 5.65%
# Benchmark return : 123.57%
# Number of trades: 5
# Number of win: 4
# Hit ratio: 80.00%
# Investment period: 1.9yrs
# Sharpe ratio: 0.42
# MDD: -25.89%
# Benchmark MDD: -31.43%

# %%
fs.indicator_to_signal(df, factor = 'rsi', buy = 60, sell = 40)
fs.position(df)
fs.evaluate(df,cost=.001)
fs.performance(df,rf_rate=0.01)
fs.draw_chart(df, left = 'rsi', right = 'position_chart')
fs.draw_chart(df, left = 'acc_rtn_dp', right = 'AAPL')
# Out:
# CAGR: 30.87%
# Accumulated return: 68.63%
# Average return: 12.51%
# Benchmark return : 123.57%
# Number of trades: 5
# Number of win: 3
# Hit ratio: 60.00%
# Investment period: 1.9yrs
# Sharpe ratio: 0.95
# MDD: -30.45%
# Benchmark MDD: -31.43%
